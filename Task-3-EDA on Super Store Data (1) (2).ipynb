# %% [markdown]
# # THE SPARKS FOUNDATION
#
# # GRADUATE ROTATIONAL INTERNSHIP PROGRAM ( GRIP )

# %% [markdown]
# # Data Science & Business Analytics Intern

# %% [markdown]
# ## Task-3:

# %% [markdown]
# Exploratory Data Analysis - Retail

# %% [markdown]
# ## Aim :

# %% [markdown]
# Perform 'Exploratory Data Analysis' on dataset 'SampleSuperstore'.

# %% [markdown]
# As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# What all business problems you can derive by exploring the data?

# %% [markdown]
# ## Dataset :

# %% [markdown]
# https://bit.ly/3j4rbWI

# %% [markdown]
# ### Lets begin the tasks...

# %% [markdown]
# ## Author: Aishwarya Parulekar

# %% [markdown]
# ### Here we go....

# %% [markdown]
# ## Step-1: Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step-2: Loading the Datasets

# %%
SSD = pd.read_csv(r"C:\Users\Dell\Downloads\SampleSuperstore.csv")
Initial_Shape = SSD.shape
Initial_Shape
# Out:
# (9994, 13)

# %% [markdown]
# ## Step-3: Inspecting the Data & Data Cleaning

# %%
SSD.drop_duplicates(keep= 'first',inplace=True)

# %%
Final_Shape = SSD.shape
Final_Shape
# Out:
# (9977, 13)

# %%
Initial_Shape[0]- Final_Shape[0]
# Out:
# 17

# %%
SSD
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# Identical Rows have been Identified and Removed in Step-3!

# %%
SSD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
SSD.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
SSD.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
SSD['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=SSD['Ship Mode'])

# %%
SSD['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.countplot(x = 'Segment',data = SSD, palette = 'rainbow')

# %%
SSD['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ## Questionaries.......

# %% [markdown]
# ### Q1 | Can you tell Top 10 States by Sales and Profits?

# %%
Top10Sales = SSD.groupby("State").Sales.sum().nlargest(n=10)
Top10Sales.index
# Out:
# Index(['California', 'New York', 'Texas', 'Washington', 'Pennsylvania',
#        'Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia'],
#       dtype='object', name='State')

# %% [markdown]
# #### Top 10 States by Sales:

# %% [markdown]
# 'California', 'New York', 'Texas', 'Washington', 'Pennsylvania',
#        'Florida', 'Illinois', 'Ohio', 'Michigan', 'Virginia'

# %%
plt.style.use('seaborn')
Top10Sales.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Sales",fontsize =13)
plt.title("Top 10 States by Sales",fontsize =16)
plt.show()

# %%
Top10Profits = SSD.groupby("State").Profit.sum().nlargest(n=10)
Top10Profits.index
# Out:
# Index(['California', 'New York', 'Washington', 'Michigan', 'Virginia',
#        'Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware'],
#       dtype='object', name='State')

# %% [markdown]
# #### Top 10 States by Profit:

# %% [markdown]
# 'California', 'New York', 'Washington', 'Michigan', 'Virginia',
#        'Indiana', 'Georgia', 'Kentucky', 'Minnesota', 'Delaware'

# %%
plt.style.use('seaborn')
Top10Profits.plot(kind ='bar', figsize =(14,8), fontsize =14)
plt.xlabel("States", fontsize =13)
plt.ylabel("Total Profits",fontsize =13)
plt.title("Top 10 States by Profits",fontsize =16)
plt.show()

# %% [markdown]
# ### Q2 | What are Total Sales and Profits of the company?

# %%
Sales_and_Profits = SSD.groupby("Segment").sum().iloc[:,[1,-1]].sum()
round(Sales_and_Profits,2) 
# Rounding Numericala entries to 2 decimal places
# Out:
# Sales     2296195.59
# Profit     286241.42
# dtype: float64

# %% [markdown]
# ### Total Sales = 2,296,195.59 USD

# %% [markdown]
# ### Total Profit = 286,241.42 USD

# %% [markdown]
# Hence, its identified that there is no co-relation between Profit and Discount.

# %% [markdown]
# ### Q3 | Graphically describe the 'Distribution of Profit and Sales' based on Categories, Segment and Region.

# %% [markdown]
# ### Categorial Distribution of Profit and Sales

# %%
SSD.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['green','orange'],alpha=0.9,figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Segment based distribution of Profit and Sales.

# %%
SSD.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['green','orange'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Regional Distribution of Profit/Loss and Sales.

# %%
SSD.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['green','orange'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))

sns.barplot(x='Sub-Category',y='Profit', data=SSD, palette='Spectral')

plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
# Out:
# Text(0.5,0.98,'Pie Consumption Patterns in the United States')

# %%
figsize=(15,10)
sns.pairplot(SSD,hue='Sub-Category')

# %% [markdown]
# ### Profit distribution by Region

# %% [markdown]
# ## Case : " Furniture " Category is the only loss making sector that to only in Central Region

# %%
gb_Central = list(SSD.groupby("Region"))[0][1]

# %%
plt.figure(figsize = (12,4))
sns.set(font_scale=1.5, palette= "viridis")
sns.barplot(data = gb_Central, x = "Category",y = "Profit" ,hue = "Ship Mode")
plt.title("Investigation of central region: Profit making(by Ship Mode)")
plt.show()

# %% [markdown]
# ### Losses are inccured in Furniture Cateory irrespective to ship mode in Central Region

# %%
gb_Category_Furniture =list(list(SSD.groupby("Region"))[0][1].groupby("Category"))[0][1]

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1.4)
sns.heatmap(gb_Category_Furniture.corr() , annot = True, cmap ="Reds")
plt.show()

# %% [markdown]
# There is unusually high positive correlation between Postal Code and Discount
#
# Also, Their is negative correlation between Discount and Sales eventhough dicounts are entered as positive values... i.e. they are not helping in improving sales of "Furniture" category of the company

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Sub-Category")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Sub Category)", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Profit" ,hue = "Segment")
plt.title("Investigation of Central Region Furniture Category: Profit Analysis(by Segment)", fontsize = 20)
plt.show()

# %% [markdown]
# Texas and Illinois are only two states contributing to all the losses in Furniture category in the Central Region
# Losses in Tables Sub Category is significanlty high.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1, palette= "viridis")
sns.barplot(data = gb_Category_Furniture , x = "State",y = "Discount" ,hue = "Sub-Category")
plt.title("Discounts provided by each state", fontsize = 20)
plt.show()

# %% [markdown]
# Texas and Illinois are only states providing discounts in the whole central region this justifies high positive correlation between postal codes and discounts.
# Also, these discounts are very high!
# 1. 60% on Furnishings
# 2. 30% on Bookcases and Chairs
# 3. 50% disount on Tables in Illinois and 30% in Texas
# 4. Are these discounts driving sales up?.... NO!

# %% [markdown]
# Joint plot for studying overall relationship between Sales and Discounts.

# %% [markdown]
# ### Step-5: Using Cluster Analysis(K-Mean Clustering)

# %%
x = SSD.iloc[:, [9, 10, 11, 12]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0).fit(x)
    wcss.append(kmeans.inertia_)

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(SSD, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Quantity')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(SSD, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Profit')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# ### Interpretion

# %% [markdown]
# From the Above data Visualization and Clustering we can see that in which states and in which Category Sales and profits are High or less. We can improve in that States By Providing Discounts in prefered Range so that Company and cosumer both will be in profit. So For Deciding that Range we have to do some Technical Analysis. One can Do it through Factor Analysis,or also can Do it throgh neural networks.

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# From All these analysis we finally conclude that,

# %% [markdown]
# 1) If we give more Discount on products our sales goes increses but Profit get down.

# %% [markdown]
# 2) In Technology category business we get more Profit as compared to other two business.These is because of we given less Discount.

# %% [markdown]
# 3) Here we also focus on our Office Supplies category business because sales of these category is less as compared to other two.

# %% [markdown]
# 4) Also Sales in 'Fasteners','labels'and 'Art' category are so weak. We need to give more attention on these sub-category businesses.

# %% [markdown]
# 5) To rise the profits , we first need to sell consumer segment products more.

# %% [markdown]
# 6) For enhancing the profits , we need to sell more to the states which are liking our products like NEWYORK and CALIFORNIA.

# %% [markdown]
# Hence To get good profit in any business you have to focus on increasing sales but not giving more discount

# %% [markdown]
# # Thank You!
